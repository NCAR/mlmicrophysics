# %%
# plot a map of PRECL differences between TAU and Emulated and Between Control KK200 and TAU, with the RMSE

# %%
# Packages
import numpy as np
import scipy.io.netcdf as S
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from scipy import interpolate
import mpl_toolkits.basemap as bm
import xarray as xr
import esmlab
import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 10]
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')
# Out:
# /glade/derecho/scratch/wchuang/tmp/ipykernel_17193/1193198533.py:14: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('png', 'pdf')

# %%
# Model data

pth='/glade/derecho/scratch/wchuang/archive/'

cases=['run12_kk2000_12month_rerun',
       'run12_tau_12month_rerun',
       'run12_1nn_optimized_1month_rerun',
       'run12_3nn_add_CLD_lev_FREQR_12month_proper_rerun',
      ]

cstxt=['Control',
       'TAU',
       'TAU 1nn',
       'TAU 3nn',
      ]

tmp = [pth + s for s in cases]
fspec = [s + '/atm/hist/' for s in tmp]

nr = len(cases)

# %%
fn=fspec[0]+'*.h1*'
d1 = xr.open_mfdataset(fn)

# %%
d1
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 192, lon: 288, time: 33, lev: 32, ilev: 33,
#                    trop_cld_lev: 32, nbnd: 2)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon           (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lev           (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * trop_cld_lev  (trop_cld_lev) float64 3.643 7.595 14.36 ... 957.5 976.3 992.6
#   * time          (time) object 2005-01-01 00:00:00 ... 2005-01-31 16:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/54)
#     gw            (time, lat) float64 dask.array<chunksize=(32, 192), meta=np.ndarray>
#     hyam          (time, lev) float64 dask.array<chunksize=(32, 32), meta=np.ndarray>
#     hybm          (time, lev) float64 dask.array<chunksize=(32, 32), meta=np.ndarray>
# ...

# %%
  mfilt   = 1, 240
  nhtfrq  = 0, -3
  avgflag_pertape = 'A','A'
  fincl1  = ['FREQS','FREQR','LANDFRAC','PRECT','PRECL']
  fincl2 = ['PRECL','PRECC','PRECT']
