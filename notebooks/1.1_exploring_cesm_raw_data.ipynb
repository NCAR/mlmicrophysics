# %%
import netCDF4 as nc
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the NetCDF file
file_path = '/glade/work/wchuang/mlmicrophysics/cesm_output/tauREV4/cam_ml_tauREV4_train.cam.h1.2005-01-01-00000.nc'  # Replace with your NetCDF file path
dataset = nc.Dataset(file_path)
ds = xr.open_dataset(file_path)

# %%
ds["time"][0]
# Out:
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2005, 1, 1, 0, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2005-01-01 00:00:00
# Attributes:
#     long_name:  time
#     bounds:     time_bnds

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 192, lon: 288, lev: 32, ilev: 33, trop_cld_lev: 32,
#                    time: 32, nbnd: 2)
# Coordinates:
#   * lat           (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon           (lon) float64 0.0 1.25 2.5 3.75 ... 355.0 356.2 357.5 358.8
#   * lev           (lev) float64 3.643 7.595 14.36 24.61 ... 957.5 976.3 992.6
#   * ilev          (ilev) float64 2.255 5.032 10.16 18.56 ... 967.5 985.1 1e+03
#   * trop_cld_lev  (trop_cld_lev) float64 3.643 7.595 14.36 ... 957.5 976.3 992.6
#   * time          (time) object 2005-01-01 00:00:00 ... 2005-01-30 17:00:00
# Dimensions without coordinates: nbnd
# Data variables: (12/45)
#     gw            (lat) float64 ...
#     hyam          (lev) float64 ...
#     hybm          (lev) float64 ...
#     P0            float64 ...
#     hyai          (ilev) float64 ...
#     hybi          (ilev) float64 ...
#     ...            ...
#     RHO_CLUBB     (time, lev, lat, lon) float64 ...
#     T             (time, lev, lat, lon) float64 ...
#     nctend_TAU    (time, trop_cld_lev, lat, lon) float64 ...
#     nrtend_TAU    (time, trop_cld_lev, lat, lon) float64 ...
#     qctend_TAU    (time, trop_cld_lev, lat, lon) float64 ...
#     qrtend_TAU    (time, trop_cld_lev, lat, lon) float64 ...
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              cam_ml_tauREV4_train
#     logname:           andrew
#     host:              derecho4
#     initial_file:      /glade/campaign/cesm/cesmdata/inputdata/atm/cam/inic/f...
#     topography_file:   /glade/campaign/cesm/cesmdata/inputdata/atm/cam/topo/f...
#     model_doi_url:     not_set
#     time_period_freq:  hour_23

# %%
# 1. Print basic information about the NetCDF file
def print_basic_info(dataset):
    print("File format:", dataset.file_format)
    print("\nGlobal Attributes:")
    for attr in dataset.ncattrs():
        print(f"{attr}: {dataset.getncattr(attr)}")
    
    print("\nDimensions:")
    for dim in dataset.dimensions.values():
        print(dim)
        
    print("\nVariables:")
    for var in dataset.variables.values():
        print(var)
        
print_basic_info(dataset)
# Out:
# File format: NETCDF3_64BIT_OFFSET
#
# Global Attributes:
# Conventions: CF-1.0
# source: CAM
# case: cam_ml_tauREV4_train
# logname: andrew
# host: derecho4
# initial_file: /glade/campaign/cesm/cesmdata/inputdata/atm/cam/inic/fv/cami-mam3_0000-01-01_0.9x1.25_L32_c141031.nc
# topography_file: /glade/campaign/cesm/cesmdata/inputdata/atm/cam/topo/fv_0.9x1.25_nc3000_Nsw042_Nrs008_Co060_Fi001_ZR_sgh30_24km_GRNL_c170103.nc
# model_doi_url: not_set
# time_period_freq: hour_23
#
# Dimensions:
# <class 'netCDF4._netCDF4.Dimension'>: name = 'lat', size = 192
# <class 'netCDF4._netCDF4.Dimension'>: name = 'lon', size = 288
# <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 32
# <class 'netCDF4._netCDF4.Dimension'>: name = 'nbnd', size = 2
# <class 'netCDF4._netCDF4.Dimension'>: name = 'chars', size = 8
# <class 'netCDF4._netCDF4.Dimension'>: name = 'lev', size = 32
# <class 'netCDF4._netCDF4.Dimension'>: name = 'ilev', size = 33
# <class 'netCDF4._netCDF4.Dimension'>: name = 'trop_cld_lev', size = 32
# <class 'netCDF4._netCDF4.Dimension'>: name = 'bins_ncd', size = 35
#
# Variables:
# <class 'netCDF4._netCDF4.Variable'>
# float64 lat(lat)
#     long_name: latitude
#     units: degrees_north
# unlimited dimensions:
# current shape = (192,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 lon(lon)
#     long_name: longitude
#     units: degrees_east
# unlimited dimensions:
# current shape = (288,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 gw(lat)
#     long_name: latitude weights
# unlimited dimensions:
# current shape = (192,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 lev(lev)
#     long_name: hybrid level at midpoints (1000*(A+B))
#     units: hPa
#     positive: down
#     standard_name: atmosphere_hybrid_sigma_pressure_coordinate
#     formula_terms: a: hyam b: hybm p0: P0 ps: PS
# unlimited dimensions:
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 hyam(lev)
#     long_name: hybrid A coefficient at layer midpoints
# unlimited dimensions:
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 hybm(lev)
#     long_name: hybrid B coefficient at layer midpoints
# unlimited dimensions:
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 P0()
#     long_name: reference pressure
#     units: Pa
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 ilev(ilev)
#     long_name: hybrid level at interfaces (1000*(A+B))
#     units: hPa
#     positive: down
#     standard_name: atmosphere_hybrid_sigma_pressure_coordinate
#     formula_terms: a: hyai b: hybi p0: P0 ps: PS
# unlimited dimensions:
# current shape = (33,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 hyai(ilev)
#     long_name: hybrid A coefficient at layer interfaces
# unlimited dimensions:
# current shape = (33,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 hybi(ilev)
#     long_name: hybrid B coefficient at layer interfaces
# unlimited dimensions:
# current shape = (33,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 trop_cld_lev(trop_cld_lev)
#     long_name: troposphere hybrid level at midpoints (1000*(A+B))
#     units: hPa
#     positive: down
# unlimited dimensions:
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     long_name: time
#     units: days since 2005-01-01 00:00:00
#     calendar: noleap
#     bounds: time_bnds
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 date(time)
#     long_name: current date (YYYYMMDD)
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 datesec(time)
#     long_name: current seconds of current date
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 time_bnds(time, nbnd)
#     long_name: time interval endpoints
# unlimited dimensions: time
# current shape = (32, 2)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 date_written(time, chars)
# unlimited dimensions: time
# current shape = (32, 8)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# |S1 time_written(time, chars)
# unlimited dimensions: time
# current shape = (32, 8)
# filling on, default _FillValue of  used
# <class 'netCDF4._netCDF4.Variable'>
# int32 ndbase()
#     long_name: base day
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 nsbase()
#     long_name: seconds of base day
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 nbdate()
#     long_name: base date (YYYYMMDD)
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 nbsec()
#     long_name: seconds of base date
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 mdt()
#     long_name: timestep
#     units: s
# unlimited dimensions:
# current shape = ()
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 ndcur(time)
#     long_name: current day (from base day)
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 nscur(time)
#     long_name: current seconds of current day
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 co2vmr(time)
#     long_name: co2 volume mixing ratio
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 ch4vmr(time)
#     long_name: ch4 volume mixing ratio
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 n2ovmr(time)
#     long_name: n2o volume mixing ratio
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 f11vmr(time)
#     long_name: f11 volume mixing ratio
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 f12vmr(time)
#     long_name: f12 volume mixing ratio
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 sol_tsi(time)
#     long_name: total solar irradiance
#     units: W/m2
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# int32 nsteph(time)
#     long_name: current timestep
# unlimited dimensions: time
# current shape = (32,)
# filling on, default _FillValue of -2147483647 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 CLOUD(time, lev, lat, lon)
#     mdims: 1
#     units: fraction
#     long_name: Cloud fraction
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 FREQR(time, lev, lat, lon)
#     mdims: 1
#     units: fraction
#     long_name: Fractional occurrence of rain
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 LAMC(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: unitless
#     long_name: Size distribution parameter lambda for liquid
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 LAMR(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: unitless
#     long_name: Size distribution parameter lambda for rain
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 N0R(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: unitless
#     long_name: Size distribution parameter n0 for rain
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 NC_TAU_in(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: 1/kg
#     long_name: nc in TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 NC_TAU_out(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: 1/kg
#     long_name: nc out TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 NR_TAU_in(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: 1/kg
#     long_name: nr in TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 NR_TAU_out(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: 1/kg
#     long_name: nr out TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 PGAM(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: unitless
#     long_name: Size distribution parameter mu (pgam) for liquid
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 QC_TAU_in(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: kg/kg
#     long_name: qc in TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 QC_TAU_out(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: kg/kg
#     long_name: qc out TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 QR_TAU_in(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: kg/kg
#     long_name: qr in TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 QR_TAU_out(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: kg/kg
#     long_name: qr out TAU
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 RHO_CLUBB(time, lev, lat, lon)
#     mdims: 1
#     units: kg/m3
#     long_name: Air Density
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 T(time, lev, lat, lon)
#     mdims: 1
#     units: K
#     long_name: Temperature
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 nctend_TAU(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: 1/kg/s
#     long_name: nc tendency due to TAU bin code
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 nrtend_TAU(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: 1/kg/s
#     long_name: nr tendency due to TAU bin code
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 qctend_TAU(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: kg/kg/s
#     long_name: qc tendency due to TAU bin code
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used
# <class 'netCDF4._netCDF4.Variable'>
# float64 qrtend_TAU(time, trop_cld_lev, lat, lon)
#     mdims: 3
#     units: kg/kg/s
#     long_name: qr tendency due to TAU bin code
# unlimited dimensions: time
# current shape = (32, 32, 192, 288)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
### 2. List all variables and their dimensions
def list_variables(dataset):
    for var_name, variable in dataset.variables.items():
        print(f"\nVariable: {var_name}")
        print("Dimensions:", variable.dimensions)
        print("Shape:", variable.shape)
        print("Attributes:")
        for attr in variable.ncattrs():
            print(f"  {attr}: {variable.getncattr(attr)}")
            
list_variables(dataset)
# Out:
# Variable: lat
# Dimensions: ('lat',)
# Shape: (192,)
# Attributes:
#   long_name: latitude
#   units: degrees_north
#
# Variable: lon
# Dimensions: ('lon',)
# Shape: (288,)
# Attributes:
#   long_name: longitude
#   units: degrees_east
#
# Variable: gw
# Dimensions: ('lat',)
# Shape: (192,)
# Attributes:
#   long_name: latitude weights
#
# Variable: lev
# Dimensions: ('lev',)
# Shape: (32,)
# Attributes:
#   long_name: hybrid level at midpoints (1000*(A+B))
#   units: hPa
#   positive: down
#   standard_name: atmosphere_hybrid_sigma_pressure_coordinate
#   formula_terms: a: hyam b: hybm p0: P0 ps: PS
#
# Variable: hyam
# Dimensions: ('lev',)
# Shape: (32,)
# Attributes:
#   long_name: hybrid A coefficient at layer midpoints
#
# Variable: hybm
# Dimensions: ('lev',)
# Shape: (32,)
# Attributes:
#   long_name: hybrid B coefficient at layer midpoints
#
# Variable: P0
# Dimensions: ()
# Shape: ()
# Attributes:
#   long_name: reference pressure
#   units: Pa
#
# Variable: ilev
# Dimensions: ('ilev',)
# Shape: (33,)
# Attributes:
#   long_name: hybrid level at interfaces (1000*(A+B))
#   units: hPa
#   positive: down
#   standard_name: atmosphere_hybrid_sigma_pressure_coordinate
#   formula_terms: a: hyai b: hybi p0: P0 ps: PS
#
# Variable: hyai
# Dimensions: ('ilev',)
# Shape: (33,)
# Attributes:
#   long_name: hybrid A coefficient at layer interfaces
#
# Variable: hybi
# Dimensions: ('ilev',)
# Shape: (33,)
# Attributes:
#   long_name: hybrid B coefficient at layer interfaces
#
# Variable: trop_cld_lev
# Dimensions: ('trop_cld_lev',)
# Shape: (32,)
# Attributes:
#   long_name: troposphere hybrid level at midpoints (1000*(A+B))
#   units: hPa
#   positive: down
#
# Variable: time
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: time
#   units: days since 2005-01-01 00:00:00
#   calendar: noleap
#   bounds: time_bnds
#
# Variable: date
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: current date (YYYYMMDD)
#
# Variable: datesec
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: current seconds of current date
#
# Variable: time_bnds
# Dimensions: ('time', 'nbnd')
# Shape: (32, 2)
# Attributes:
#   long_name: time interval endpoints
#
# Variable: date_written
# Dimensions: ('time', 'chars')
# Shape: (32, 8)
# Attributes:
#
# Variable: time_written
# Dimensions: ('time', 'chars')
# Shape: (32, 8)
# Attributes:
#
# Variable: ndbase
# Dimensions: ()
# Shape: ()
# Attributes:
#   long_name: base day
#
# Variable: nsbase
# Dimensions: ()
# Shape: ()
# Attributes:
#   long_name: seconds of base day
#
# Variable: nbdate
# Dimensions: ()
# Shape: ()
# Attributes:
#   long_name: base date (YYYYMMDD)
#
# Variable: nbsec
# Dimensions: ()
# Shape: ()
# Attributes:
#   long_name: seconds of base date
#
# Variable: mdt
# Dimensions: ()
# Shape: ()
# Attributes:
#   long_name: timestep
#   units: s
#
# Variable: ndcur
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: current day (from base day)
#
# Variable: nscur
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: current seconds of current day
#
# Variable: co2vmr
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: co2 volume mixing ratio
#
# Variable: ch4vmr
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: ch4 volume mixing ratio
#
# Variable: n2ovmr
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: n2o volume mixing ratio
#
# Variable: f11vmr
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: f11 volume mixing ratio
#
# Variable: f12vmr
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: f12 volume mixing ratio
#
# Variable: sol_tsi
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: total solar irradiance
#   units: W/m2
#
# Variable: nsteph
# Dimensions: ('time',)
# Shape: (32,)
# Attributes:
#   long_name: current timestep
#
# Variable: CLOUD
# Dimensions: ('time', 'lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 1
#   units: fraction
#   long_name: Cloud fraction
#
# Variable: FREQR
# Dimensions: ('time', 'lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 1
#   units: fraction
#   long_name: Fractional occurrence of rain
#
# Variable: LAMC
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: unitless
#   long_name: Size distribution parameter lambda for liquid
#
# Variable: LAMR
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: unitless
#   long_name: Size distribution parameter lambda for rain
#
# Variable: N0R
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: unitless
#   long_name: Size distribution parameter n0 for rain
#
# Variable: NC_TAU_in
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: 1/kg
#   long_name: nc in TAU
#
# Variable: NC_TAU_out
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: 1/kg
#   long_name: nc out TAU
#
# Variable: NR_TAU_in
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: 1/kg
#   long_name: nr in TAU
#
# Variable: NR_TAU_out
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: 1/kg
#   long_name: nr out TAU
#
# Variable: PGAM
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: unitless
#   long_name: Size distribution parameter mu (pgam) for liquid
#
# Variable: QC_TAU_in
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: kg/kg
#   long_name: qc in TAU
#
# Variable: QC_TAU_out
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: kg/kg
#   long_name: qc out TAU
#
# Variable: QR_TAU_in
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: kg/kg
#   long_name: qr in TAU
#
# Variable: QR_TAU_out
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: kg/kg
#   long_name: qr out TAU
#
# Variable: RHO_CLUBB
# Dimensions: ('time', 'lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 1
#   units: kg/m3
#   long_name: Air Density
#
# Variable: T
# Dimensions: ('time', 'lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 1
#   units: K
#   long_name: Temperature
#
# Variable: nctend_TAU
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: 1/kg/s
#   long_name: nc tendency due to TAU bin code
#
# Variable: nrtend_TAU
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: 1/kg/s
#   long_name: nr tendency due to TAU bin code
#
# Variable: qctend_TAU
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: kg/kg/s
#   long_name: qc tendency due to TAU bin code
#
# Variable: qrtend_TAU
# Dimensions: ('time', 'trop_cld_lev', 'lat', 'lon')
# Shape: (32, 32, 192, 288)
# Attributes:
#   mdims: 3
#   units: kg/kg/s
#   long_name: qr tendency due to TAU bin code

# %%
ds2 = ds.drop_vars(['P0', 'ndbase', 'nsbase', 'nbdate', 'nbsec', 'mdt'])

# %%
filter_mask = (ds2.data_vars['CLOUD'] > 1e-2) & (ds2.data_vars['QC_TAU_in'] > 1e-6)

# %%
sum(sum(sum(sum(filter_mask))))

# %%
sum(sum(sum(sum(cloud_array))))
# Out:
# <xarray.DataArray 'CLOUD' ()>
# array(11956490)

# %%
# 3. Summary statistics for each variable
def summarize_variables(ds):
    print("\nSummary Statistics:")
    for var in ds.data_vars:
        print(f"\nVariable: {var}")
        print(ds[var].to_series().describe())

summarize_variables(ds2)
# Out:
# Summary Statistics:
#
# Variable: gw
# count    192.000000
# mean       0.010417
# std        0.005118
# min        0.000034
# 25%        0.006263
# 50%        0.011582
# 75%        0.015156
# max        0.016447
# Name: gw, dtype: float64
#
# Variable: hyam
# count    32.000000
# mean      0.071518
# std       0.058274
# min       0.000000
# 25%       0.020759
# 50%       0.056599
# 75%       0.121676
# max       0.178231
# Name: hyam, dtype: float64
#
# Variable: hybm
# count    32.000000
# mean      0.326108
# std       0.389771
# min       0.000000
# 25%       0.000000
# 50%       0.087696
# 75%       0.730823
# max       0.992556
# Name: hybm, dtype: float64
#
# Variable: hyai
# count    33.000000
# mean      0.069328
# std       0.059041
# min       0.000000
# 25%       0.018555
# 50%       0.056240
# 75%       0.113876
# max       0.181863
# Name: hyai, dtype: float64
#
# Variable: hybi
# count    33.000000
# mean      0.331378
# std       0.395544
# min       0.000000
# 25%       0.000000
# 50%       0.085654
# 75%       0.753628
# max       1.000000
# Name: hybi, dtype: float64
#
# Variable: date
# count    3.200000e+01
# mean     2.005012e+07
# std      9.031977e+00
# min      2.005010e+07
# 25%      2.005011e+07
# 50%      2.005012e+07
# 75%      2.005012e+07
# max      2.005013e+07
# Name: date, dtype: float64
#
# Variable: datesec
# count       32.000000
# mean     46800.000000
# std      27001.935415
# min          0.000000
# 25%      24300.000000
# 50%      52200.000000
# 75%      69300.000000
# max      82800.000000
# Name: datesec, dtype: float64
#
# Variable: time_bnds
# count                      64
# unique                     32
# top       2005-01-01 00:00:00
# freq                        3
# Name: time_bnds, dtype: object
#
# Variable: date_written
# count              32
# unique              1
# top       b'12/22/23'
# freq               32
# Name: date_written, dtype: object
#
# Variable: time_written
# count              32
# unique             32
# top       b'20:01:01'
# freq                1
# Name: time_written, dtype: object
#
# Variable: ndcur
# count    32.000000
# mean     14.312500
# std       9.031977
# min       0.000000
# 25%       6.750000
# 50%      14.500000
# 75%      22.250000
# max      29.000000
# Name: ndcur, dtype: float64
#
# Variable: nscur
# count       32.000000
# mean     46800.000000
# std      27001.935415
# min          0.000000
# 25%      24300.000000
# 50%      52200.000000
# 75%      69300.000000
# max      82800.000000
# Name: nscur, dtype: float64
#
# Variable: co2vmr
# count    3.200000e+01
# mean     3.780278e-04
# std      4.729777e-08
# min      3.779496e-04
# 25%      3.779887e-04
# 50%      3.780278e-04
# 75%      3.780669e-04
# max      3.781059e-04
# Name: co2vmr, dtype: float64
#
# Variable: ch4vmr
# count    3.200000e+01
# mean     1.783758e-06
# std      2.143205e-11
# min      1.783723e-06
# 25%      1.783740e-06
# 50%      1.783758e-06
# 75%      1.783776e-06
# max      1.783794e-06
# Name: ch4vmr, dtype: float64
#
# Variable: n2ovmr
# count    3.200000e+01
# mean     3.187760e-07
# std      1.904005e-11
# min      3.187445e-07
# 25%      3.187603e-07
# 50%      3.187760e-07
# 75%      3.187917e-07
# max      3.188075e-07
# Name: n2ovmr, dtype: float64
#
# Variable: f11vmr
# count    3.200000e+01
# mean     7.182585e-10
# std      1.945612e-13
# min      7.179370e-10
# 25%      7.180977e-10
# 50%      7.182585e-10
# 75%      7.184192e-10
# max      7.185799e-10
# Name: f11vmr, dtype: float64
#
# Variable: f12vmr
# count    3.200000e+01
# mean     5.424674e-10
# std      1.729697e-14
# min      5.424388e-10
# 25%      5.424531e-10
# 50%      5.424674e-10
# 75%      5.424817e-10
# max      5.424960e-10
# Name: f12vmr, dtype: float64
#
# Variable: sol_tsi
# count    32.0
# mean     -1.0
# std       0.0
# min      -1.0
# 25%      -1.0
# 50%      -1.0
# 75%      -1.0
# max      -1.0
# Name: sol_tsi, dtype: float64
#
# Variable: nsteph
# count      32.00000
# mean      713.00000
# std       431.51825
# min         0.00000
# 25%       356.50000
# 50%       713.00000
# 75%      1069.50000
# max      1426.00000
# Name: nsteph, dtype: float64
#
# Variable: CLOUD
# count    5.662310e+07
# mean     1.146975e-01
# std      2.886256e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.131382e-04
# max      1.000000e+00
# Name: CLOUD, dtype: float64
#
# Variable: FREQR
# count    5.662310e+07
# mean     1.817787e-02
# std      1.199312e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.000000e+00
# Name: FREQR, dtype: float64
#
# Variable: LAMC
# count    5.662310e+07
# mean     1.067550e+05
# std      4.514448e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.555556e+06
# Name: LAMC, dtype: float64
#
# Variable: LAMR
# count    5.662310e+07
# mean     3.985468e+03
# std      9.208559e+03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.962983e+03
# max      5.000000e+04
# Name: LAMR, dtype: float64
#
# Variable: N0R
# count    5.662310e+07
# mean     9.014619e+10
# std      1.169858e+12
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      6.027535e-04
# max      1.989437e+13
# Name: N0R, dtype: float64
#
# Variable: NC_TAU_in
# count    5.662310e+07
# mean     3.740514e+06
# std      1.929366e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.621790e+09
# Name: NC_TAU_in, dtype: float64
#
# Variable: NC_TAU_out
# count    5.662310e+07
# mean     2.582364e+06
# std      1.666838e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.621644e+09
# Name: NC_TAU_out, dtype: float64
#
# Variable: NR_TAU_in
# count    5.662310e+07
# mean     2.117772e+06
# std      2.431056e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      3.835127e-08
# max      3.978874e+08
# Name: NR_TAU_in, dtype: float64
#
# Variable: NR_TAU_out
# count    5.662310e+07
# mean     1.395507e+18
# std      1.050085e+22
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.175532e-05
# max      7.901714e+25
# Name: NR_TAU_out, dtype: float64
#
# Variable: PGAM
# count    5.662310e+07
# mean    -7.786023e+01
# std      4.353891e+01
# min     -1.000000e+02
# 25%     -1.000000e+02
# 50%     -1.000000e+02
# 75%     -1.000000e+02
# max      1.011111e+01
# Name: PGAM, dtype: float64
#
# Variable: QC_TAU_in
# count    5.662310e+07
# mean     3.248706e-05
# std      2.274371e-04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.000000e-03
# Name: QC_TAU_in, dtype: float64
#
# Variable: QC_TAU_out
# count    5.662310e+07
# mean     7.382538e-06
# std      3.090775e-05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.719691e-03
# Name: QC_TAU_out, dtype: float64
#
# Variable: QR_TAU_in
# count    5.662310e+07
# mean     3.798200e-04
# std      1.809701e-03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      5.667952e-17
# max      1.000000e-02
# Name: QR_TAU_in, dtype: float64
#
# Variable: QR_TAU_out
# count    5.662310e+07
# mean     4.049245e-04
# std      1.834185e-03
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      3.508809e-16
# max      1.500000e-02
# Name: QR_TAU_out, dtype: float64
#
# Variable: RHO_CLUBB
# count    5.662310e+07
# mean     5.200581e-01
# std      4.362542e-01
# min      4.438465e-03
# 25%      1.106976e-01
# 50%      3.866664e-01
# 75%      9.589963e-01
# max      1.636317e+00
# Name: RHO_CLUBB, dtype: float64
#
# Variable: T
# count    5.662310e+07
# mean     2.391031e+02
# std      2.869880e+01
# min      1.765052e+02
# 25%      2.151474e+02
# 50%      2.326301e+02
# 75%      2.622783e+02
# max      3.159914e+02
# Name: T, dtype: float64
#
# Variable: nctend_TAU
# count    5.662310e+07
# mean    -1.931700e+03
# std      1.305270e+04
# min     -3.868475e+06
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      0.000000e+00
# Name: nctend_TAU, dtype: float64
#
# Variable: nrtend_TAU
# count    5.662310e+07
# mean     2.325844e+15
# std      1.750142e+19
# min     -6.631456e+05
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.316952e+23
# Name: nrtend_TAU, dtype: float64
#
# Variable: qctend_TAU
# count    5.662310e+07
# mean    -4.184086e-08
# std      3.716447e-07
# min     -8.333333e-06
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      0.000000e+00
# Name: qctend_TAU, dtype: float64
#
# Variable: qrtend_TAU
# count    5.662310e+07
# mean     4.184086e-08
# std      3.716447e-07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      8.333333e-06
# Name: qrtend_TAU, dtype: float64

# %%
# 4. Basic plot of a variable (replace 'variable_name' with an actual variable name from your dataset)
def plot_variable(ds, var_name):
    if var_name not in ds.variables:
        print(f"{var_name} not found in dataset.")
        return

    data = ds[var_name]
    if data.ndim == 2:  # 2D plot for simple spatial data
        data.plot()
        plt.title(f"{var_name} (2D Plot)")
    elif data.ndim == 3:  # 3D plot for time-series spatial data
        time_slice = data.isel(time=0)  # Select the first time slice
        time_slice.plot()
        plt.title(f"{var_name} at time=0")
    else:
        print(f"Cannot plot variable '{var_name}' with dimensions {data.ndim}")
    plt.show()

plot_variable(ds, 'CLDLIQ')  # Replace 'variable_name' with an actual variable name

# %%
# 5. Close the dataset when done
dataset.close()
ds.close()
